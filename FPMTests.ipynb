# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import h5py
from scipy import misc
import numpy as np

out_file = './out_sampling/sample_intest.npy'


image_dict = np.load(out_file)

im_array = image_dict[()][(230, 20)]
ax = plt.gca()
imgplot = ax.imshow(im_array,clim=(0.0, 255.0))
imgplot.set_cmap('gray')
plt.show()
plt.hist(im_array.ravel(), bins=50, range=(0.0, 255.0), fc='k', ec='k')
plt.show()

# %%
plt.hist(im_array.ravel(), bins=50, range=(0.0, 255.0), fc='k', ec='k')
plt.show()
